# %% [markdown]
# # OpenAI 调用大模型
#
# ## 0.准备工作
#
# 首先，我们需要安装OpenAI的依赖
# 安装命令：
# ```shell
# uv add openai
# ```

# %% [markdown]
# ## 1.初始化客户端
#
# ### 1.1.硬编码API_KEY

# %%
from openai import OpenAI

# 创建 OpenAI 客户端
client = OpenAI(
    api_key="sk-REPLACE_WITH_YOUR_KEY",
    base_url="https://api.deepseek.com"
)

# %% [markdown]
# ### 1.2. 从环境变量中获取API_KEY

# %% [markdown]
# 读取环境变量需要用到python-dotenv，先安装依赖
# 安装命令：
# ```shell
# uv add python-dotenv
# ```
# 再创建.env文件，并写入api_key
# ```properties
# DEEPSEEK_API_KEY=sk-REPLACE_WITH_YOUR_KEY
# ```
# 接着就可以可以从环境变量中获取api_key了

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("DEEPSEEK_API_KEY")
print(api_key)

client = OpenAI(
    api_key=api_key,
    base_url="https://api.deepseek.com"
)
# Out:
# sk-REPLACE_WITH_YOUR_KEY

# %% [markdown]
# ## 2.访问模型

# %%
print("🚀 正在调用大模型...")
response = client.chat.completions.create(
    model="deepseek-v4-flash",
    messages=[
        {"role": "system", "content": "你是一名友好的AI助教。"},
        {"role": "user", "content": "你好，你是谁?"}
    ],
    stream=False,
    temperature=0.9,
)
print("🚀 成功调用大模型...")
# Out:
# 🚀 正在调用大模型...
# 🚀 成功调用大模型...

# %% [markdown]
# ## 3.获取模型响应结果

# %%
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "c34d833d-978d-4bb3-84e6-d49eb41758c5",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": "你好呀！我是你的AI助教，一个友好又热心的智能助手。你可以把我当成随时在线的朋友，不管是学习上的问题、生活中的困惑，还是只是想聊聊天，我都非常乐意帮你！有什么可以为你效劳的吗？😊",
#         "refusal": null,
#         "role": "assistant",
#         "annotations": null,
#         "audio": null,
#         "function_call": null,
#         "tool_calls": null,
#         "reasoning_content": "嗯，用户问“你好，你是谁？”，这是一个简单的自我介绍问题。需要明确告知用户我的身份和基本功能。用户可能是初次接触，需要友好亲切的回应。\n\n想到了用“你好呀”开头，营造轻松氛围。直接说明我是AI助教，强调是朋友和帮手，主动提供帮助建立信任。最后用开放性问题引导对话继续，比如“有什么可以帮你的”，保持主动和关怀的态度。\n\n注意语气要热情，避免复杂术语，让用户感到亲切可信。"
#       }
#     }
#   ],
#   "created": 1784986355,
#   "model": "deepseek-v4-flash",
#   "object": "chat.completion",
#   "moderation": null,
#   "service_tier": null,
#   "system_fingerprint": "fp_8b330d02d0_prod0820_fp8_kvcache_20260402",
#   "usage": {
#     "completion_tokens": 156,
#     "prompt_tokens": 15,
#     "total_tokens": 171,
#     "completion_tokens_details": {
#       "accepted_prediction_tokens": null,
#       "audio_tokens": null,
#       "reasoning_tokens": 103,
#       "rejected_prediction_tokens": null
#     },
#     "prompt_tokens_details": {
#       "audio_tokens": null,
#       "cache_write_tokens": null,
#       "cached_tokens": 0
#     },
#     "prompt_cache_hit_tokens": 0,
#     "prompt_cache_miss_tokens": 15
#   }
# }

# %%
print(response.choices[0].message.content)
# Out:
# 你好呀！我是你的AI助教，一个友好又热心的智能助手。你可以把我当成随时在线的朋友，不管是学习上的问题、生活中的困惑，还是只是想聊聊天，我都非常乐意帮你！有什么可以为你效劳的吗？😊
